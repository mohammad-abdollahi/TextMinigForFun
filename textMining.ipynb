# %%
import numpy as np
import pandas as pd

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer

# %%
text = pd.read_csv("text_mining.csv").drop(["document_id"],axis=1)
text = text[text['direction']==1]
tex2 = text[(text['category_id']==1) | (text['category_id']==8)]

# %%
text.head()
# Out:
#    category_id   news_id                                               text  \
# 0            5  771144.0  سرعت رشد صادرات بیش از واردات \n تراز بازرگانی...
# 1            5  484118.0  دوره آموزشی آشنایی با اصول و مقررات صادرات و و...
# 2            5  762478.0  67 درصد صادرات خراسان جنوبی از بازارچه ها انجا...
# 3            5  890085.0  80 درصد صادرات اردبیل را سیب زمینی تشکیل می ده...
# 4            5  744852.0  ماموریت اتاق بازرگانی و فرصت های طلایی صادرات ...
#
#    direction
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
cliCon = text[text['category_id']==1]
politCon = text[text['category_id']==8]

# %%
cliCon.head()
# Out:
#       category_id    news_id  \
# 2022            1  1050208.0
# 2023            1      992.0
# 2024            1   101394.0
# 2025            1   250969.0
# 2026            1  1953961.0
#
#                                                    text  direction
# 2022  هواشناسی برای گلستان یخبندان و کاهش دما را پیش...          1
# 2023  آغاز دوباره بارش برف و باران در نوار شمالی کشو...          1
# 2024  احتمال بارش برف و باران از اواخر وقت امروز در ...          1
# 2025  کاهش نسبی دمای هوا در مازندران / بارش برف و با...          1
# 2026  باران و برف در آذربایجان غربی طی هفته آینده/ ت...          1

# %%
cli = ''
for i in cliCon.text.as_matrix(): cli = cli + ' ' + i
pol = ''
for i in politCon.text.as_matrix(): pol = pol + ' ' + i
# Out:
# /home/mohammad/.local/lib/python2.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# /home/mohammad/.local/lib/python2.7/site-packages/ipykernel_launcher.py:4: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   after removing the cwd from sys.path.

# %%
from hazm import stopwords_list,Stemmer
stm = Stemmer()
sw = stopwords_list()
swFilt = []
for i in sw:
    i = i.encode("utf-8")
    swFilt.append(i)

# %%
filt = ""
w = cli.split()
for i in w:
    if i not in swFilt and i != "است.":
        filt = filt + i +" "
w = filt.split()
cli_filt = ""
for i in w:
    i = i.decode("utf-8")
    j = stm.stem(i)
    j.encode("utf-8")
    cli_filt = cli_filt + j + " "

# %%
filt = ""
w = pol.split()
for i in w:
    if i not in swFilt and i != "است.":
        filt = filt + i +" "
w = filt.split()
pol_filt = ""
for i in w:
    i = i.decode("utf-8")
    j = stm.stem(i)
    j.encode("utf-8")
    pol_filt = pol_filt + j + " "

# %%
content = [cli_filt, pol_filt]

# %%
cv = CountVectorizer()
cv.fit(content)
cv_doc = cv.transform(content)

# %%
df = pd.DataFrame(cv_doc.toarray().transpose(), index = cv.get_feature_names())

# %%
df.sort_values(0, ascending=False)
# Out:
#            0     1
# بار      234    33
# اس       213    49
# br       131     0
# روز      124   344
# هوا       94    56
# آب        89    47
# برف       82     0
# ابر       71     3
# گفت       65   220
# بین       64    23
# کرد       63   526
# کشور      59  1697
# سال       55   655
# کاه       53    75
# بارندگ    52     0
# وضع       52   100
# یزد       50     0
# خواهد     50   310
# باد       49     4
# دما       48     0
# هواشناس   47     0
# افزا      45   149
# وز        45     1
# درصد      44    76
# مناطق     43    70
# افزود     42    84
# شنبه      42    87
# شود       41   283
# شمال      39   143
# ادامه     37   175
# ...      ...   ...
# حلق        0     2
# حما        0   191
# حوال       0     1
# حیثیت      0     1
# حیث        0     1
# حیاط       0     4
# حیات       0     4
# حکومت      0     6
# حکوم       0    32
# حکم        0     6
# حکا        0     4
# حک         0    26
# حومه       0    11
# حوضچه      0     1
# حوث        0    12
# حواش       0     2
# حماس       0    30
# حوادث      0    14
# حواتمه     0     5
# حنیف       0     5
# حنف        0     9
# حمیدی      0     2
# حمید       0     4
# حمود       0     1
# حمله       0   158
# حملات      0     6
# حمل        0   128
# حمریت      0     1
# حمد        0     5
# سراسر      0    16
#
# [8489 rows x 2 columns]

# %%
tfidf = TfidfVectorizer()
tfidf_doc = tfidf.fit_transform(content)

# %%
df2 = pd.DataFrame(tfidf_doc.toarray().transpose(), index =tfidf.get_feature_names())

# %%
df2.sort_values(0, ascending=False)
# Out:
#                 0         1
# بار      0.419115  0.007245
# اس       0.381502  0.010758
# br       0.329768  0.000000
# روز      0.222095  0.075523
# برف      0.206420  0.000000
# هوا      0.168362  0.012294
# آب       0.159407  0.010319
# بارندگ   0.130900  0.000000
# ابر      0.127167  0.000659
# یزد      0.125866  0.000000
# دما      0.120831  0.000000
# هواشناس  0.118314  0.000000
# گفت      0.116421  0.048300
# بین      0.114630  0.005050
# کرد      0.112839  0.115480
# کشور     0.105674  0.372566
# سال      0.098510  0.143801
# کاه      0.094928  0.016466
# وضع      0.093137  0.021954
# خواهد    0.089554  0.068059
# باد      0.087763  0.000878
# وز       0.080599  0.000220
# افزا     0.080599  0.032712
# درصد     0.078808  0.016685
# مناطق    0.077017  0.015368
# افزود    0.075226  0.018442
# شنبه     0.075226  0.019100
# شود      0.073435  0.062131
# شمال     0.069852  0.031395
# ادامه    0.066270  0.038420
# ...           ...       ...
# حلق      0.000000  0.000617
# حما      0.000000  0.058935
# حوال     0.000000  0.000309
# حیثیت    0.000000  0.000309
# حیث      0.000000  0.000309
# حیاط     0.000000  0.001234
# حیات     0.000000  0.001234
# حکومت    0.000000  0.001851
# حکوم     0.000000  0.009874
# حکم      0.000000  0.001851
# حکا      0.000000  0.001234
# حک       0.000000  0.008023
# حومه     0.000000  0.003394
# حوضچه    0.000000  0.000309
# حوث      0.000000  0.003703
# حواش     0.000000  0.000617
# حماس     0.000000  0.009257
# حوادث    0.000000  0.004320
# حواتمه   0.000000  0.001543
# حنیف     0.000000  0.001543
# حنف      0.000000  0.002777
# حمیدی    0.000000  0.000617
# حمید     0.000000  0.001234
# حمود     0.000000  0.000309
# حمله     0.000000  0.048753
# حملات    0.000000  0.001851
# حمل      0.000000  0.039496
# حمریت    0.000000  0.000309
# حمد      0.000000  0.001543
# سراسر    0.000000  0.004937
#
# [8489 rows x 2 columns]

# %%
tmp = []
for i in tex2['text']:
    i = i.split()
    filt=""
    for j in i:
        if j not in swFilt:
            filt = filt + j +" "
    tmp.append(filt)
tex2['text'] = tmp 
print tex2.head()
from sklearn.model_selection import train_test_split
y, z = train_test_split(tex2, test_size=.2)
# Out:
#      category_id    news_id  \
# 942            8   490245.0
# 943            8  1258198.0
# 944            8   648991.0
# 945            8   864821.0
# 946            8      882.0
#
#                                                   text  direction
# 942  موافقت اردن مبادله تروریست اسیر ژاپنی بند داعش...          1
# 943  داعش مسجد تاریخی موصل منفجر گزارش گروه الملل خ...          1
# 944  عقب نشینی ناگهانی اعضای خارجی داعش خیابان های ...          1
# 945  جان بولتون: اوباما ده سال مقاومت غرب ایران باد...          1
# 946  کاخ سفید سیاست خارجی محتاطانه عمل گزارش گروه ا...          1
# /home/mohammad/.local/lib/python2.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()

# %%
model.fit(tfidf.fit_transform(y.text).toarray(), y.category_id)
# Out:
# GaussianNB(priors=None)

# %%
from sklearn.metrics import classification_report
print(classification_report(z.category_id, model.predict(tfidf.transform(z.text).toarray())))
# Out:
#              precision    recall  f1-score   support
#
#           1       1.00      0.80      0.89         5
#           8       0.99      1.00      0.99        89
#
# avg / total       0.99      0.99      0.99        94

# %%
from sklearn.tree import DecisionTreeClassifier
tr = DecisionTreeClassifier()
tr.fit(tfidf.fit_transform(y.text).toarray(), y.category_id)
print(classification_report(z.category_id, tr.predict(tfidf.transform(z.text).toarray())))
# Out:
#              precision    recall  f1-score   support
#
#           1       1.00      0.80      0.89         5
#           8       0.99      1.00      0.99        89
#
# avg / total       0.99      0.99      0.99        94

# %%
x = text
tmp = []
for i in x['text']:
    if (isinstance(i, float) == False ):
        i = i.split()
        filt=""
        for j in i:
            if j not in swFilt and j != "است.":
                filt = filt + j +" "
        tmp.append(filt)
    else:
        tmp.append("")
x['text'] = tmp 
print x.head()
y, z = train_test_split(x, test_size=.2)
# Out:
#    category_id   news_id                                               text  \
# 0            5  771144.0  سرعت صادرات واردات تراز بازرگانی ایران ترکیه ک...
# 1            5  484118.0  دوره آموزشی آشنایی اصول مقررات صادرات واردات ب...
# 2            5  762478.0  67 درصد صادرات خراسان جنوبی بازارچه ها انجام گ...
# 3            5  890085.0  80 درصد صادرات اردبیل سیب زمینی تشکیل گزارش خب...
# 4            5  744852.0  ماموریت اتاق بازرگانی فرصت های طلایی صادرات گز...
#
#    direction
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
from sklearn.tree import DecisionTreeClassifier
tr = DecisionTreeClassifier()
tr.fit(tfidf.fit_transform(y.text).toarray(), y.category_id)
print(classification_report(z.category_id, tr.predict(tfidf.transform(z.text).toarray())))
# Out:
#              precision    recall  f1-score   support
#
#           1       0.19      0.50      0.27         6
#           2       0.67      0.29      0.40         7
#           3       0.33      0.36      0.35        47
#           5       0.48      0.37      0.42        30
#           8       0.77      0.78      0.77        85
#           9       0.80      0.67      0.73        18
#          10       0.29      0.17      0.21        12
#          11       0.12      0.14      0.13         7
#          12       0.59      0.74      0.66        31
#          13       0.71      0.67      0.69        43
#          14       0.79      0.73      0.76        30
#          16       0.00      0.00      0.00         4
#          17       0.89      0.65      0.76        26
#          18       0.86      0.95      0.90        96
#
# avg / total       0.67      0.67      0.67       442

# %%
model.fit(tfidf.fit_transform(y.text).toarray(), y.category_id)
print(classification_report(z.category_id, model.predict(tfidf.transform(z.text).toarray())))
# Out:
#              precision    recall  f1-score   support
#
#           1       0.80      0.67      0.73         6
#           2       1.00      0.29      0.44         7
#           3       0.60      0.81      0.69        47
#           5       0.73      0.80      0.76        30
#           8       0.88      0.98      0.93        85
#           9       0.92      0.67      0.77        18
#          10       1.00      0.17      0.29        12
#          11       0.25      0.14      0.18         7
#          12       0.89      0.81      0.85        31
#          13       0.75      0.91      0.82        43
#          14       0.96      0.80      0.87        30
#          16       1.00      0.25      0.40         4
#          17       0.95      0.73      0.83        26
#          18       0.92      0.96      0.94        96
#
# avg / total       0.84      0.83      0.82       442

# %%
from sklearn.linear_model import LogisticRegression
logic = LogisticRegression().fit(tfidf.fit_transform(y.text).toarray(), y.category_id)
print(classification_report(z.category_id, logic.predict(tfidf.transform(z.text).toarray())))
# Out:
#              precision    recall  f1-score   support
#
#           1       0.75      0.50      0.60         6
#           2       0.71      0.71      0.71         7
#           3       0.82      0.96      0.88        47
#           5       0.87      0.90      0.89        30
#           8       0.88      1.00      0.93        85
#           9       1.00      0.83      0.91        18
#          10       1.00      0.25      0.40        12
#          11       0.00      0.00      0.00         7
#          12       1.00      0.90      0.95        31
#          13       0.96      1.00      0.98        43
#          14       1.00      0.93      0.97        30
#          16       0.00      0.00      0.00         4
#          17       1.00      0.88      0.94        26
#          18       0.91      1.00      0.95        96
#
# avg / total       0.89      0.91      0.89       442

# %%
from sklearn.linear_model import LogisticRegressionCV
logicCV = LogisticRegressionCV().fit(tfidf.fit_transform(y.text).toarray(), y.category_id)
print(classification_report(z.category_id, logicCV.predict(tfidf.transform(z.text).toarray())))
# Out:
#              precision    recall  f1-score   support
#
#           1       0.50      0.83      0.62         6
#           2       0.86      0.86      0.86         7
#           3       0.95      0.83      0.89        47
#           5       0.97      0.97      0.97        30
#           8       0.99      1.00      0.99        85
#           9       1.00      0.94      0.97        18
#          10       1.00      0.75      0.86        12
#          11       0.50      0.86      0.63         7
#          12       1.00      0.97      0.98        31
#          13       1.00      1.00      1.00        43
#          14       1.00      1.00      1.00        30
#          16       1.00      1.00      1.00         4
#          17       1.00      1.00      1.00        26
#          18       0.99      1.00      0.99        96
#
# avg / total       0.97      0.96      0.96       442
